# %%
import boto3
import pandas as pd

s3=boto3.client('s3')

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='us-west-2',
    aws_access_key_id='',
    aws_secret_access_key=''
)

# %%
buck=s3.Bucket('lms29')

#for obj in buck.objects.all():
    #print(obj.key)

# %% [markdown]
# ### Reading CSV Files from the bucket

# %%
obj1=buck.Object('csv/df1.csv').get()
df1=pd.read_csv(obj1['Body'])

# %%
df1
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 954            7.6              0.43         0.40             2.7      0.082
# 955            8.5              0.21         0.52             1.9      0.090
# 956            9.0              0.36         0.52             2.1      0.111
# 957            9.5              0.37         0.52             2.0      0.088
# 958            6.4              0.57         0.12             2.3      0.120
#
# ...

# %%
obj2=buck.Object('csv/df2.csv').get()
df2=pd.read_csv(obj2['Body'])

# %%
df2
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              8.0             0.590         0.05             2.0      0.089
# 1              8.5             0.470         0.27             1.9      0.058
# 2              7.1             0.560         0.14             1.6      0.078
# 3              6.6             0.570         0.02             2.1      0.115
# 4              8.8             0.270         0.39             2.0      0.100
# ..             ...               ...          ...             ...        ...
# 315            7.8             0.580         0.13             2.1      0.102
# 316            8.0             0.715         0.22             2.3      0.075
# 317            8.5             0.400         0.40             6.3      0.050
# 318            7.0             0.690         0.00             1.9      0.114
# 319            8.0             0.715         0.22             2.3      0.075
#
# ...

# %%
obj3=buck.Object('csv/df3.csv').get()
df3=pd.read_csv(obj3['Body'])

# %%
df3
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              9.8             0.300         0.39             1.7      0.062
# 1              7.1             0.460         0.20             1.9      0.077
# 2              7.1             0.460         0.20             1.9      0.077
# 3              7.9             0.765         0.00             2.0      0.084
# 4              8.7             0.630         0.28             2.7      0.096
# ..             ...               ...          ...             ...        ...
# 315            6.2             0.600         0.08             2.0      0.090
# 316            5.9             0.550         0.10             2.2      0.062
# 317            6.3             0.510         0.13             2.3      0.076
# 318            5.9             0.645         0.12             2.0      0.075
# 319            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Combining Dataset

# %%
df=pd.concat([df1,df2,df3])

# %%
df=df.reset_index()

# %%
df
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.4             0.700         0.00             1.9
# 1         1            7.8             0.880         0.00             2.6
# 2         2            7.8             0.760         0.04             2.3
# 3         3           11.2             0.280         0.56             1.9
# 4         4            7.4             0.700         0.00             1.9
# ...     ...            ...               ...          ...             ...
# 1594    315            6.2             0.600         0.08             2.0
# 1595    316            5.9             0.550         0.10             2.2
# 1596    317            6.3             0.510         0.13             2.3
# 1597    318            5.9             0.645         0.12             2.0
# 1598    319            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %% [markdown]
# ### Specifying Train and Test Dataset

# %%
train=df1

# %%
train
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 4              7.4              0.70         0.00             1.9      0.076
# ..             ...               ...          ...             ...        ...
# 954            7.6              0.43         0.40             2.7      0.082
# 955            8.5              0.21         0.52             1.9      0.090
# 956            9.0              0.36         0.52             2.1      0.111
# 957            9.5              0.37         0.52             2.0      0.088
# 958            6.4              0.57         0.12             2.3      0.120
#
# ...

# %%
test=pd.concat([df2,df3])

# %%
test=test.reset_index()

# %%
testf=test.iloc[:,1:13]

# %%
testf
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              8.0             0.590         0.05             2.0      0.089
# 1              8.5             0.470         0.27             1.9      0.058
# 2              7.1             0.560         0.14             1.6      0.078
# 3              6.6             0.570         0.02             2.1      0.115
# 4              8.8             0.270         0.39             2.0      0.100
# ..             ...               ...          ...             ...        ...
# 635            6.2             0.600         0.08             2.0      0.090
# 636            5.9             0.550         0.10             2.2      0.062
# 637            6.3             0.510         0.13             2.3      0.076
# 638            5.9             0.645         0.12             2.0      0.075
# 639            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# ### Saving Train and Test Dataset as CSV file

# %%
train.to_csv('automl-train.csv', index=False, header=True, sep=',') # Need to keep column names
testf.to_csv('automl-test.csv', index=False, header=True, sep=',')

# %%
import sagemaker

sess=sagemaker.Session()
lm=sess.upload_data(path="automl-train.csv")
print(lm)
# Out:
# s3://sagemaker-us-west-2-313830654669/data/automl-train.csv

# %% [markdown]
# ### After Autopilot Experiment, Best model is deployed as endpoint

# %%
ep_name = 'bestmodel29'

# %%
import boto3,sys

sm_rt = boto3.Session().client('runtime.sagemaker')

# %% [markdown]
# ### Checking the results against the labels of test dataset

# %%
res=[]
with open('automl-test.csv') as f:
    lines = f.readlines()
    for l in lines[1:]:   
        l = l.split(',')  
        label = l[-1]     
        l = l[:-1]        
        l = ','.join(l)   
                
        response = sm_rt.invoke_endpoint(EndpointName=ep_name, ContentType='text/csv', Accept='text/csv', Body=l)

        response = response['Body'].read().decode("utf-8")
        res.append(response[0])
        #print ("label %s response %s" %(label,response))

# %%
testf['Predicted']=res

# %%
testf.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            8.0              0.59         0.05             2.0      0.089
# 1            8.5              0.47         0.27             1.9      0.058
# 2            7.1              0.56         0.14             1.6      0.078
# 3            6.6              0.57         0.02             2.1      0.115
# 4            8.8              0.27         0.39             2.0      0.100
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 12.0                  32.0  0.99735  3.36       0.61
# 1                 18.0                  38.0  0.99518  3.16       0.85
# 2                  7.0                  18.0  0.99592  3.27       0.62
# 3                  6.0                  16.0  0.99654  3.38       0.69
# 4                 20.0                  27.0  0.99546  3.15       0.69
#
#    alcohol  quality Predicted
# 0     10.0        5         6
# ...
